# %%
import csv
wait_list=[]
# with open('stock_list_for_test.csv') as f:#供小型測試用
with open('stock_list.csv',encoding="utf-8") as f:
    list_of_stock = csv.DictReader(f)
    n=1
    for obj in list_of_stock:
#         wait_list.append(obj['stock_id'])
        n=n+1
        if n%33==0:
            wait_list.append(obj['stock_id'])

# %%
wait_list

# %%
def Try(stockNo,Name):    
    import requests
    import pandas as pd
    import time
    from datetime import datetime
    import sys
    
    temp = sys.stdout                 # store original stdout object for later
    sys.stdout = open('log.txt', 'a') # redirect all prints to this log file
    
#     if str(obj['stock_id']) in wait_list:
#         print("靜待一小時．．．")
#         time.sleep (3600)    
#         print("一小時要結束啦～")

    starttime=datetime.now() #紀錄多久
    
    # 個股PER、PBR資料表 TaiwanStockPER
    url = "https://api.finmindtrade.com/api/v4/data"
    parameter = {
        "dataset": "TaiwanStockPER",
        "data_id": stockNo,
        "start_date": "2000-01-01",
        "token": "",
    }
    data = requests.get(url, params=parameter)
    data = data.json()
    data = pd.DataFrame(data['data'])
    if data.empty != True:
        file_name = "TaiwanStockPER/{}_TaiwanStockPER.csv".format(stockNo)
        data.to_csv(file_name, index=False)
        print(file_name+"下載完成...")
    else:
        print(stockNo+"TaiwanStockPER為空")
        
    # 股東結構表 TaiwanStockShareholding
    url = "https://api.finmindtrade.com/api/v4/data"
    parameter = {
        "dataset": "TaiwanStockShareholding",
        "data_id": stockNo,
        "start_date": "2000-01-01",
        "token": "", # 參考登入，獲取金鑰
    }
    data = requests.get(url, params=parameter)
    data = data.json()
    data = pd.DataFrame(data['data'])
    if data.empty != True:
        file_name = "TaiwanStockShareholding/{}_TaiwanStockShareholding.csv".format(stockNo)
        data.to_csv(file_name, index=False)
        print(file_name+"下載完成...")
    else:
        print(stockNo+"TaiwanStockShareholding為空")
        
    # 借券成交明細 TaiwanStockSecuritiesLending
    url = "https://api.finmindtrade.com/api/v4/data"
    parameter = {
        "dataset": "TaiwanStockSecuritiesLending",
        "data_id": stockNo,
        "start_date": "2000-01-01",
        "token": "", # 參考登入，獲取金鑰
    }
    data = requests.get(url, params=parameter)
    data = data.json()
    data = pd.DataFrame(data['data'])
    if data.empty != True:
        file_name = "TaiwanStockSecuritiesLending/{}_TaiwanStockSecuritiesLending.csv".format(stockNo)
        data.to_csv(file_name, index=False)
        print(file_name+"下載完成...")
    else:
        print(stockNo+"TaiwanStockSecuritiesLending為空")
        
    # 當日沖銷交易標的及成交量值 TaiwanStockDayTrading
    url = "https://api.finmindtrade.com/api/v4/data"
    parameter = {
        "dataset": "TaiwanStockDayTrading",
        "data_id": stockNo,
        "start_date": "2000-01-01",
        "end_date": "2021-04-28",
        "token": "", # 參考登入，獲取金鑰
    }
    resp = requests.get(url, params=parameter)
    data = resp.json()
    data = pd.DataFrame(data["data"])
    if data.empty != True:
        file_name = "TaiwanStockDayTrading/{}_TaiwanStockDayTrading.csv".format(stockNo)
        data.to_csv(file_name, index=False)
        print(file_name+"下載完成...")
    else:
        print(stockNo+"TaiwanStockDayTrading為空")
    
    # 資產負債表 TaiwanStockBalanceSheet
    url = "https://api.finmindtrade.com/api/v4/data"
    parameter = {
        "dataset": "TaiwanStockBalanceSheet",
        "data_id": stockNo,
        "start_date": "2000-01-01",
        "token": "", # 參考登入，獲取金鑰
    }
    data = requests.get(url, params=parameter)
    data = data.json()
    data = pd.DataFrame(data['data'])
    if data.empty != True:
        file_name = "TaiwanStockBalanceSheet/{}_TaiwanStockBalanceSheet.csv".format(stockNo)
        data.to_csv(file_name, index=False)
        print(file_name+"下載完成...")
    else:
        print(stockNo+"TaiwanStockBalanceSheet為空")
        
    # 現金流量表 TaiwanStockCashFlowsStatement
    url = "https://api.finmindtrade.com/api/v4/data"
    parameter = {
        "dataset": "TaiwanStockCashFlowsStatement",
        "data_id": stockNo,
        "start_date": "2000-01-01",
        "token": "", # 參考登入，獲取金鑰
    }
    data = requests.get(url, params=parameter)
    data = data.json()
    data = pd.DataFrame(data['data'])
    if data.empty != True:
        file_name = "TaiwanStockCashFlowsStatement/{}_TaiwanStockCashFlowsStatement.csv".format(stockNo)
        data.to_csv(file_name, index=False)
        print(file_name+"下載完成...")
    else:
        print(stockNo+"TaiwanStockCashFlowsStatement為空")
    
    # 股利政策表 TaiwanStockDividend
    url = "https://api.finmindtrade.com/api/v4/data"
    parameter = {
        "dataset": "TaiwanStockDividend",
        "data_id": stockNo,
        "start_date": "2000-01-01",
        "token": "", # 參考登入，獲取金鑰
    }
    data = requests.get(url, params=parameter)
    data = data.json()
    data = pd.DataFrame(data['data'])
    if data.empty != True:
        file_name = "TaiwanStockDividend/{}_TaiwanStockDividend.csv".format(stockNo)
        data.to_csv(file_name, index=False)
        print(file_name+"下載完成...")
    else:
        print(stockNo+"TaiwanStockDividend為空")
    
    # 月營收表 TaiwanStockMonthRevenue
    url = "https://api.finmindtrade.com/api/v4/data"
    parameter = {
        "dataset": "TaiwanStockMonthRevenue",
        "data_id": stockNo,
        "start_date": "2000-01-01",
        "token": "", # 參考登入，獲取金鑰
    }
    data = requests.get(url, params=parameter)
    data = data.json()
    data = pd.DataFrame(data['data'])
    if data.empty != True:
        file_name = "TaiwanStockMonthRevenue/{}_TaiwanStockMonthRevenue.csv".format(stockNo)
        data.to_csv(file_name, index=False)
        print(file_name+"下載完成...")
    else:
        print(stockNo+"TaiwanStockMonthRevenue為空")
        
    # 相關新聞表 TaiwanStockNews
    import requests
    import pandas as pd
    url = "https://api.finmindtrade.com/api/v4/data"
    parameter = {
        "dataset": "TaiwanStockNews",
        "data_id":stockNo,
        "start_date": "2000-01-01",
        "end_date": "2021-04-28",
        "token": "", # 參考登入，獲取金鑰
    }
    data = requests.get(url, params=parameter)
    data = data.json()
    data = pd.DataFrame(data['data'])
    if data.empty != True:
        file_name = "TaiwanStockNews/{}_TaiwanStockNews.csv".format(stockNo)
        data.to_csv(file_name, index=False)
        print(file_name+"下載完成...")
    else:
        print(stockNo+"TaiwanStockNews為空")
        
    endtime= datetime.now() #紀錄爬取該支股票要多久
    print("執行時間:",endtime-starttime,"秒") #紀錄爬取該支股票要多久
    sys.stdout.close()          # ordinary file object
    sys.stdout = temp           # restore print commands to interactive prompt
    print(stockNo,Name,'完成')   # this shows up in the interactive prompt

# %%
import csv
# with open('stock_list_for_test.csv') as f:#供小型測試用
with open('stock_list.csv',encoding="utf-8") as f:
    list_of_stock = csv.DictReader(f)
#     for obj in list_of_stock:
#         Try(obj['stock_id'],obj['stock_name'])
        
    stop = 2354
    stop = str(stop)
    num = 0
    
    #找Index值，從成功的下一隻股票開始找
    for obj in list_of_stock:
        if obj['stock_id'] == stop:
            num = 1
            continue
        if num :
            Try(obj['stock_id'],obj['stock_name'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-34b7239151b4> in <module>
#      16             continue
#      17         if num :
# ---> 18             Try(obj['stock_id'],obj['stock_name'])
#
# <ipython-input-1-07295eaa10a8> in Try(stockNo, Name)
#     133         "token": "", # 參考登入，獲取金鑰
#     134     }
# --> 135     data = requests.get(url, params=parameter)
#     136     data = data.json()
#     137     data = pd.DataFrame(data['data'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
# ...
