# %%
#https://finmind.github.io/tutor/TaiwanMarket/DataList/

# %%
#法人買賣表 TaiwanStockInstitutionalInvestorsBuySell
#表格格式：日期/股票代碼/買進/類別/賣出
#英文對照：date/stock_id/buy/name/sell/
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockInstitutionalInvestorsBuySell",
    "data_id": "2330",
    "start_date": "2020-04-01",
    "token": "", # 參考登入，獲取金鑰
}
data = requests.get(url, params=parameter)
data = data.json()
data = pd.DataFrame(data['data'])
print(data.head())
print(data.info())
# Out:
#          date stock_id       buy                 name      sell
# 0  2020-04-01     2330    189000       Dealer_Hedging    493500
# 1  2020-04-01     2330     79000          Dealer_self    807000
# 2  2020-04-01     2330         0  Foreign_Dealer_Self         0
# 3  2020-04-01     2330  31304729     Foreign_Investor  29057663
# 4  2020-04-01     2330    900000     Investment_Trust    239000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1290 entries, 0 to 1289
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      1290 non-null   object
#  1   stock_id  1290 non-null   object
#  2   buy       1290 non-null   int64
#  3   name      1290 non-null   object
#  4   sell      1290 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 50.5+ KB
# None

# %%
#台灣市場整體法人買賣表 TaiwanStockTotalInstitutionalInvestors
#表格格式：
#英文對照：
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockTotalInstitutionalInvestors",
    "start_date": "2020-04-01",
    "token": "", # 參考登入，獲取金鑰
}
data = requests.get(url, params=parameter)
data = data.json()
data = pd.DataFrame(data['data'])
print(data.head())
print(data.info())
# Out:
#            buy        date                 name         sell
# 0       123150  2020-04-01  Foreign_Dealer_Self       266220
# 1  41269248850  2020-04-01                total  45771643971
# 2    789316840  2020-04-01          Dealer_self    912143500
# 3   3681729831  2020-04-01       Dealer_Hedging   5539788946
# 4  33759089839  2020-04-01     Foreign_Investor  38466572585
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1548 entries, 0 to 1547
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   buy     1548 non-null   int64
#  1   date    1548 non-null   object
#  2   name    1548 non-null   object
#  3   sell    1548 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 48.5+ KB
# None

# %%
#融資融劵表 TaiwanStockMarginPurchaseShortSale¶
#表格格式：日期/股票代碼/融資買進/融資現金償還/融資限額/融資賣出/融資今日餘額/融資昨日餘額/註記/資券互抵/融券買進/融券償還/融券限額/融券賣出/融券今日餘額/融券昨日餘額
#英文對照：date/stock_
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockMarginPurchaseShortSale",
    "data_id": "2330",
    "start_date": "2020-04-01",
    "token": "", # 參考登入，獲取金鑰
}
data = requests.get(url, params=parameter)
data = data.json()
data = pd.DataFrame(data['data'])
print(data.head())
print(data.info())
# Out:
#          date stock_id  MarginPurchaseBuy  MarginPurchaseCashRepayment  \
# 0  2020-04-01     2330               1423                          189
# 1  2020-04-06     2330               1914                            8
# 2  2020-04-07     2330               1049                           13
# 3  2020-04-08     2330               1192                            3
# 4  2020-04-09     2330                499                           28
#
#    MarginPurchaseLimit  MarginPurchaseSell  MarginPurchaseTodayBalance  \
# 0              6482595                 623                       25648
# 1              6482595                1269                       26285
# 2              6482595                2655                       24666
# 3              6482595                1569                       24286
# 4              6482595                1362                       23395
#
#    MarginPurchaseYesterdayBalance Note  OffsetLoanAndShort  ShortSaleBuy  \
# ...

# %%
#台灣市場整體融資融劵表 TaiwanStockTotalMarginPurchaseShortSale
#表格格式：今日餘額/昨日餘額/買進/日期/種類/Return（中文沒有這一列？）/賣出
#英文對照：TodayBalance/YesBalance/buy/date/name/Return/sell
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockTotalMarginPurchaseShortSale",
    "start_date": "2020-04-01",
    "token": "", # 參考登入，獲取金鑰
}
data = requests.get(url, params=parameter)
data = data.json()
data = pd.DataFrame(data['data'])
print(data.head())
print(data.info())
# Out:
#    TodayBalance   YesBalance         buy        date                 name  \
# 0       5463820      5471770      236127  2020-04-01       MarginPurchase
# 1        541704       556742       57266  2020-04-01            ShortSale
# 2   91965082000  91898116000  4046643000  2020-04-01  MarginPurchaseMoney
# 3       5496478      5463820      327741  2020-04-06       MarginPurchase
# 4        535401       541704       50779  2020-04-06            ShortSale
#
#       Return        sell
# 0      10986      233091
# 1       6151       48379
# 2  196619000  3783058000
# 3       3791      291292
# 4       3700       48176
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TodayBalance  774 non-null    int64
#  1   YesBalance    774 non-null    int64
#  2   buy           774 non-null    int64
#  3   date          774 non-null    object
# ...

# %%
#股東持股分級表 TaiwanStockHoldingSharesPer
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockHoldingSharesPer",
    "data_id": "2330",
    "start_date": "2020-04-01",
    "token": "", # 參考登入，獲取金鑰
}
data = requests.get(url, params=parameter)
data = data.json()
data = pd.DataFrame(data['data'])
print(data.head())
print(data.info())
# Out:
#          date stock_id HoldingSharesLevel  people  percent       unit
# 0  2020-04-01     2330              1-999  165122     0.12   33289900
# 1  2020-04-01     2330        1,000-5,000  227692     1.69  440404454
# 2  2020-04-01     2330      10,001-15,000   10408     0.49  128127693
# 3  2020-04-01     2330    100,001-200,000    1628     0.86  225202876
# 4  2020-04-01     2330      15,001-20,000    5068     0.34   89929303
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 895 entries, 0 to 894
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                895 non-null    object
#  1   stock_id            895 non-null    object
#  2   HoldingSharesLevel  895 non-null    object
#  3   people              895 non-null    int64
#  4   percent             895 non-null    float64
#  5   unit                895 non-null    int64
# dtypes: float64(1), int64(2), object(3)
# ...

# %%
#除權除息結果表 TaiwanStockDividendResult
#可再參考要不要用
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockDividendResult",
    "data_id": "2330",
    "start_date": "2019-01-01",
    "token": "", # 參考登入，獲取金鑰
}
data = requests.get(url, params=parameter)
data = data.json()
data = pd.DataFrame(data['data'])
print(data.head())
print(data.info())
# Out:
#          date stock_id  before_price  after_price  stock_and_cache_dividend  \
# 0  2019-06-24     2330         248.5        240.5                       8.0
# 1  2019-09-19     2330         267.0        265.0                       2.0
# 2  2019-12-19     2330         344.5        342.0                       2.5
# 3  2020-03-19     2330         260.0        257.5                       2.5
# 4  2020-06-18     2330         315.0        312.5                       2.5
#
#   stock_or_cache_dividend  max_price  min_price  open_price  reference_price
# 0                       息      264.5      216.5       240.5            240.5
# 1                       息      291.5      238.5       265.0            265.0
# 2                       息      376.0      308.0       342.0            342.0
# 3                       息      283.0      232.0       257.5            257.5
# 4                       息      343.5      281.5       312.5            312.5
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
#股價日成交資訊 TaiwanStockPrice
#表格格式：日期/股票代碼/成交量/成交金額/開盤價/最高價/最低價/收盤價/漲跌幅/交易筆數
#英文對照：date/stock_id/Trading_Volume/Trading_money/open/max/min/close/spread/Trading_turnover
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockPrice",
    "data_id": "2330",
    "start_date": "2020-04-02",
    "end_date": "2020-04-12",
    "token": "", # 參考登入，獲取金鑰
}
resp = requests.get(url, params=parameter)
data = resp.json()
data = pd.DataFrame(data["data"])
print(data.head())
print(data.info())
# Out:
#          date stock_id  Trading_Volume  Trading_money   open    max    min  \
# 0  2020-04-06     2330        59712754    16324198154  273.0  275.5  270.0
# 1  2020-04-07     2330        48887346    13817936851  283.5  284.0  280.5
# 2  2020-04-08     2330        38698826    11016972354  285.0  285.5  283.0
# 3  2020-04-09     2330        29276430     8346209654  287.5  288.0  282.5
# 4  2020-04-10     2330        28206858     7894277586  280.0  282.0  279.0
#
#    close  spread  Trading_turnover
# 0  275.5     4.0             19971
# 1  283.0     7.5             24281
# 2  285.0     2.0             19126
# 3  283.0    -2.0             15271
# 4  279.5    -3.5             15833
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              5 non-null      object
#  1   stock_id          5 non-null      object
# ...
