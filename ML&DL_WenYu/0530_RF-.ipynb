# %% [markdown]
# # *匯入查看data

# %%
import pandas as pd
all = pd.read_csv('merge_dataframe.csv', index_col=["stock_id",'date'], parse_dates=['date'])

all
# Out:
# C:\Users\Mikie\.conda\envs\finlab\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                      Unnamed: 0 stock_name     ISIN_Code Listing_date  \
# stock_id date
# 1101     2010-01-04           0         台泥  TW0001101004   1962-02-09
#          2010-01-05           1         台泥  TW0001101004   1962-02-09
#          2010-01-06           2         台泥  TW0001101004   1962-02-09
#          2010-01-07           3         台泥  TW0001101004   1962-02-09
#          2010-01-08           4         台泥  TW0001101004   1962-02-09
# ...                         ...        ...           ...          ...
# 9962     2021-04-19     4078032         有益  TW0009962001   2006-07-10
#          2021-04-20     4078033         有益  TW0009962001   2006-07-10
#          2021-04-21     4078034         有益  TW0009962001   2006-07-10
# ...

# %%
all.info()
all.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 4078037 entries, (1101, Timestamp('2010-01-04 00:00:00')) to (9962, Timestamp('2021-04-23 00:00:00'))
# Data columns (total 57 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   Unnamed: 0                        int64
#  1   stock_name                        object
#  2   ISIN_Code                         object
#  3   Listing_date                      object
#  4   Listing_category                  object
#  5   Industry_category                 object
#  6   CFICode                           object
#  7   Volume                            float64
#  8   Volume_Cash                       float64
#  9   Open                              float64
#  10  High                              float64
#  11  Low                               float64
#  12  Close                             float64
#  13  Change                            float64
# ...

# %%
open = all['Open']
close = all['Close']
high = all['High']
low = all['Low']
dividend_yield = all['dividend_yield']
PER  = all['PER']
PBR  = all['PBR']
FIRS  = all['ForeignInvestmentRemainingShares']
FISR  = all['ForeignInvestmentShares']
FIRR  = all['ForeignInvestmentRemainRatio']
FISR  = all['ForeignInvestmentSharesRatio']
FIUR  = all['ForeignInvestmentUpperLimitRatio']
CIUL  = all['ChineseInvestmentUpperLimitRatio']
RDD  = all['RecentlyDeclareDate']
# return = all[['Close']].shift(-10) 
# PBR  = all['PBR']
# open = all['Open']
# open = all['Open']
dividend_yield
dataset = pd.DataFrame({
    'Open': open,
    'Close': close,
    'High': high,
    'Low': low,
    'dividend_yield': dividend_yield,
    'PER': PER ,
    'FIRS': FIRS,
    'FISR': FISR,
    'FIRR': FIRR,
    'FISR': FISR,
    'FIUR': FIUR,
    'CIUL': CIUL,
    'FIUR': FIUR,
    
    
    'return':all['Close'].shift(-10) / all['Close']
    
})

dataset
# Out:
#                       Open  Close   High    Low  dividend_yield      PER  \
# stock_id date
# 1101     2010-01-04  34.00  34.30  34.40  33.90            3.85    18.85
#          2010-01-05  34.60  35.50  35.80  34.50            3.72    19.51
#          2010-01-06  35.50  36.25  36.40  35.40            3.64    19.92
#          2010-01-07  36.35  35.55  36.40  35.50            3.71    19.53
#          2010-01-08  35.55  35.40  35.80  35.15            3.73    19.45
# ...                    ...    ...    ...    ...             ...      ...
# 9962     2021-04-19  12.75  12.75  12.75  12.10            0.00  1275.00
#          2021-04-20  13.00  12.20  13.40  12.20            0.00  1220.00
#          2021-04-21  12.20  12.45  12.75  12.00            0.00  1245.00
#          2021-04-22  12.75  12.30  13.65  12.00            0.00  1230.00
#          2021-04-23  12.50  11.70  12.75  11.30            0.00  1170.00
#
#                              FIRS  FISR   FIRR   FIUR   CIUL    return
# ...

# %%
df= dataset.loc[2317][["Open", 'Close','High','Low','dividend_yield','PER','FIRS','FISR','FIRR','FISR','FIUR','CIUL','return']]
df
# Out:
#              Open  Close   High    Low  dividend_yield    PER          FIRS  \
# date
# 2010-01-04  152.0  151.5  152.5  150.5            1.72  23.20  3.903509e+09
# 2010-01-05  153.5  152.5  155.5  151.5            1.70  23.35  3.897532e+09
# 2010-01-06  152.5  151.5  153.0  151.5            1.72  23.20  3.901984e+09
# 2010-01-07  151.5  150.0  152.5  148.5            1.73  22.97  3.902045e+09
# 2010-01-08  150.0  150.5  151.0  147.0            1.73  23.05  3.895991e+09
# ...           ...    ...    ...    ...             ...    ...           ...
# 2021-04-19  123.5  121.5  123.5  121.5            3.29  16.55  7.068741e+09
# 2021-04-20  121.5  122.0  122.0  121.0            3.28  16.62  7.066072e+09
# 2021-04-21  121.0  120.0  121.5  120.0            3.33  16.35  7.075690e+09
# 2021-04-22  122.0  117.5  122.0  117.5            3.40  16.01  7.075889e+09
# 2021-04-23  117.0  119.0  119.0  117.0            3.36  16.21  7.069904e+09
#
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2774 entries, 2010-01-04 to 2021-04-23
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Open            2774 non-null   float64
#  1   Close           2774 non-null   float64
#  2   High            2774 non-null   float64
#  3   Low             2774 non-null   float64
#  4   dividend_yield  2747 non-null   float64
#  5   PER             2747 non-null   float64
#  6   FIRS            2369 non-null   float64
#  7   FISR            2369 non-null   float64
#  8   FIRR            2369 non-null   float64
#  9   FISR            2369 non-null   float64
#  10  FIUR            2369 non-null   float64
#  11  CIUL            2369 non-null   float64
#  12  return          2774 non-null   float64
# dtypes: float64(13)
# memory usage: 303.4 KB
# Open                0
# Close               0
# High                0
# Low                 0
# dividend_yield     27
# ...

# %%
df1=df.fillna(method='ffill')
df1.isnull().sum()
# Out:
# Open              0
# Close             0
# High              0
# Low               0
# dividend_yield    0
# PER               0
# FIRS              0
# FISR              0
# FIRR              0
# FISR              0
# FIUR              0
# CIUL              0
# return            0
# dtype: int64

# %%
feature_names = list(df1.columns[:-1])
feature_names
# Out:
# ['Open',
#  'Close',
#  'High',
#  'Low',
#  'dividend_yield',
#  'PER',
#  'FIRS',
#  'FISR',
#  'FIRR',
#  'FISR',
#  'FIUR',
#  'CIUL']

# %%
df1.dtypes
# Out:
# Open              float64
# Close             float64
# High              float64
# Low               float64
# dividend_yield    float64
# PER               float64
# FIRS              float64
# FISR              float64
# FIRR              float64
# FISR              float64
# FIUR              float64
# CIUL              float64
# return            float64
# dtype: object

# %%
dataset = df1.reset_index().set_index("date")
dataset.index.get_level_values("date")
dataset
# Out:
#              Open  Close   High    Low  dividend_yield    PER          FIRS  \
# date
# 2010-01-04  152.0  151.5  152.5  150.5            1.72  23.20  3.903509e+09
# 2010-01-05  153.5  152.5  155.5  151.5            1.70  23.35  3.897532e+09
# 2010-01-06  152.5  151.5  153.0  151.5            1.72  23.20  3.901984e+09
# 2010-01-07  151.5  150.0  152.5  148.5            1.73  22.97  3.902045e+09
# 2010-01-08  150.0  150.5  151.0  147.0            1.73  23.05  3.895991e+09
# ...           ...    ...    ...    ...             ...    ...           ...
# 2021-04-19  123.5  121.5  123.5  121.5            3.29  16.55  7.068741e+09
# 2021-04-20  121.5  122.0  122.0  121.0            3.28  16.62  7.066072e+09
# 2021-04-21  121.0  120.0  121.5  120.0            3.33  16.35  7.075690e+09
# 2021-04-22  122.0  117.5  122.0  117.5            3.40  16.01  7.075889e+09
# 2021-04-23  117.0  119.0  119.0  117.0            3.36  16.21  7.069904e+09
#
# ...

# %%
feature_names = list(dataset.columns[:-1])
feature_names
# Out:
# ['Open',
#  'Close',
#  'High',
#  'Low',
#  'dividend_yield',
#  'PER',
#  'FIRS',
#  'FISR',
#  'FIRR',
#  'FISR',
#  'FIUR',
#  'CIUL']

# %%
# scaler = preprocessing.StandardScaler().fit(dataset)
# scaler_dataset = scaler.transform(dataset)
# scaler_dataset
dataset_train = dataset.loc[:'2018']
dataset_test = dataset.loc['2019':]
X_train = dataset_train[feature_names]
y_train = dataset_train['return']
X_test = dataset_test[feature_names]
y_test = dataset_test['return']
# X_train
y_train
# Out:
# date
# 2010-01-04    0.996700
# 2010-01-05    0.977049
# 2010-01-06    0.973597
# 2010-01-07    0.973333
# 2010-01-08    0.916944
#                 ...
# 2018-12-24    0.978992
# 2018-12-25    0.980198
# 2018-12-26    0.988604
# 2018-12-27    0.970339
# 2018-12-28    0.992938
# Name: return, Length: 2217, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import xgboost
from xgboost import XGBRegressor

# %%
scaler = preprocessing.StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)

model = RandomForestClassifier(n_estimators=10)
model.fit(X_train, y_train>1)

X_test = scaler.transform(X_test)
y_pred = model.predict(X_test)


accuracy = accuracy_score(y_test>1, y_pred)
num_correct_samples = accuracy_score(y_test>1, y_pred, normalize=False)
con_matrix = confusion_matrix(y_test>1, y_pred)


print('number of correct sample: {}'.format(num_correct_samples))
print('accuracy: {}'.format(accuracy))
print('con_matrix: {}'.format(con_matrix))
# Out:
# number of correct sample: 341
# accuracy: 0.6122082585278277
# con_matrix: [[148  89]
#  [127 193]]

# %%
import numpy as np
from sklearn.metrics import classification_report
# 拿建好的模型於test data做出預測
crit = 0.5
# preds = model.predict(test_x_)
preds = y_pred.squeeze()
preds = (preds > crit).astype(np.int32)

print(classification_report(y_test>1, preds))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.54      0.62      0.58       237
#         True       0.68      0.60      0.64       320
#
#     accuracy                           0.61       557
#    macro avg       0.61      0.61      0.61       557
# weighted avg       0.62      0.61      0.61       557

# %%
from time import time
from scipy.stats import randint as sp_randint
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
# from dask_searchcv import GridSearchCV
# from dask_searchcv import RandomizedSearchCV
from sklearn.datasets import load_digits
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn", lineno=1978)

# build a classifier
clf = RandomForestClassifier(n_estimators=100)


# Utility function to report best scores
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                results['mean_test_score'][candidate],
                results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")


# specify parameters and distributions to sample from
param_dist = {"max_depth": [3, None],
              "max_features": sp_randint(1, 11),
              "min_samples_split": sp_randint(2, 11),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# run randomized search
n_iter_search = 20
random_search = RandomizedSearchCV(clf, param_distributions=param_dist,
                                   n_iter=n_iter_search)

start = time()
random_search.fit(X_train, y_train>1)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))
report(random_search.cv_results_)

# use a full grid over all parameters
param_grid = {"max_depth": [3, None],
              "max_features": [1, 3, 10],
              "min_samples_split": [2, 3, 10],
              "min_samples_leaf": [1, 3, 10],
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# run grid search
grid_search = GridSearchCV(clf, param_grid=param_grid)
start = time()
grid_search.fit(X_train, y_train>1)

print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
      % (time() - start, len(grid_search.cv_results_['params'])))
report(grid_search.cv_results_)
# Out:
# RandomizedSearchCV took 17.08 seconds for 20 candidates parameter settings.
# Model with rank: 1
# Mean validation score: 0.531 (std: 0.008)
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 2, 'min_samples_split': 6}
#
# Model with rank: 1
# Mean validation score: 0.531 (std: 0.019)
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Model with rank: 3
# Mean validation score: 0.530 (std: 0.019)
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 7, 'min_samples_split': 8}
#
# GridSearchCV took 252.11 seconds for 216 candidate parameter settings.
# Model with rank: 1
# Mean validation score: 0.547 (std: 0.031)
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
#
# ...

# %%
#save best model
rf_best = random_search.best_estimator_
rf_best

# rf_best = rf_gs.best_estimator_

# #check best n_estimators value
# print(rf_gs.best_params_)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=2, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=6,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
# X_train = scaler.transform(X_train)

model = rf_best
model.fit(X_train, y_train>1)

X_test = scaler.transform(X_test)
y_pred = model.predict(X_test)


accuracy = accuracy_score(y_test>1, y_pred)
num_correct_samples = accuracy_score(y_test>1, y_pred, normalize=False)
con_matrix = confusion_matrix(y_test>1, y_pred)


print('number of correct sample: {}'.format(num_correct_samples))
print('accuracy: {}'.format(accuracy))
print('con_matrix: {}'.format(con_matrix))
# Out:
# number of correct sample: 320
# accuracy: 0.5745062836624776
# con_matrix: [[  0 237]
#  [  0 320]]

# %%
# from sklearn.metrics import classification_report
# 拿建好的模型於test data做出預測
crit = 0.4
# preds = model.predict(test_x_)
preds = y_pred.squeeze()
preds = (preds > crit).astype(np.int32)

print(classification_report(y_test>1, preds))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.00      0.00      0.00       237
#         True       0.57      1.00      0.73       320
#
#     accuracy                           0.57       557
#    macro avg       0.29      0.50      0.36       557
# weighted avg       0.33      0.57      0.42       557
# C:\Users\Mikie\.conda\envs\finlab\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
import pandas as pd
prediction = rf_best.predict(X_test)
importance=pd.DataFrame(zip(feature_names,rf_best.feature_importances_), columns=['feature_name','importantce'])
importance= importance.sort_values("importantce", ascending=False)
importance
rf_importance=importance.head(50)
rf_importance
# Out:
#       feature_name  importantce
# 6             FIRS     0.210194
# 5              PER     0.176319
# 4   dividend_yield     0.167628
# 3              Low     0.112640
# 2             High     0.112311
# 1            Close     0.111461
# 0             Open     0.108300
# 7             FISR     0.000000
# 8             FIRR     0.000000
# 9             FISR     0.000000
# 10            FIUR     0.000000
# 11            CIUL     0.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20,15))
sns.barplot(x="importantce", y="feature_name", data=rf_importance)
plt.savefig('rf_0530.png')
