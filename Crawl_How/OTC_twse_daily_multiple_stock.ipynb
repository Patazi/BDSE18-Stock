# %% [markdown]
# # 單股每日交易量
# 表格說明：股票代碼/公司名稱/日期/成交量/成交金額/開盤價/最高價/最低價/收盤價/漲跌幅/交易筆數
# 英文對照：stock_id/stock_name/date/Volume/Volume_Cash/Open/High/Low/Close/Change/Order

# %%
def Stock_crawl_OTC(stockNo,Name):
    import csv
    import requests
    import pandas as pd
    import numpy as np
    import json as js 
    import time
    import random
    from datetime import datetime
    from tqdm import trange,tqdm

    starttime= datetime.now() #紀錄多久
    dates=[]
    # 獲取今天日期
    now_time = datetime.now().strftime('%Y%m%d')
    now_time

    url = "https://api.finmindtrade.com/api/v4/data"
    parameter = {
        "dataset": "TaiwanStockPrice",
        "data_id": stockNo,
        "start_date": "2010-01-01",
        "end_date": now_time,
        # 參考登入，獲取金鑰
        "token": "",
#         "token": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJkYXRlIjoiMjAyMS0wNC0yNCAxMToyNTo0MiIsInVzZXJfaWQiOiJ0emVob3dsZWUiLCJpcCI6IjIyMy4xMzcuMTUwLjE2MSJ9.4aJm0mu53xxUUl6p9CihpS7cvzGNYDKS1-tCEOvS4I0", 
    }
    resp = requests.get(url, params=parameter)
    data = resp.json()
    data = pd.DataFrame(data["data"])
    # print(data.head())
    # print(data.info())
    data=data[['stock_id','date','Trading_Volume','Trading_money','open','max','min','close','spread','Trading_turnover']]
    data.insert(1,column='stock_name',value=Name)
    data['Trading_Volume']=data['Trading_Volume'].astype(float)
    data['Trading_money']=data['Trading_money'].astype(float)
    data['Trading_turnover']=data['Trading_turnover'].astype(float)
    data.columns=['stock_id','stock_name','date','Volume','Volume_Cash','Open','High','Low','Close','Change','Order']

    file_name = "Finmind_daily/{}_daily.csv".format(stockNo)
    data.to_csv(file_name, index=False)
    print(file_name+"下載完成...", end="")
    endtime= datetime.now() #紀錄爬取該支股票要多久
    print("執行時間:",endtime-starttime,"秒") #紀錄爬取該支股票要多久

# %%
import csv
# with open('stock_list_for_test.csv') as f:#供小型測試用
with open('stock_list.csv') as f:
    list_of_stock = csv.DictReader(f)
    
    #設定之前已經載下來的股票代碼
    stop = 6265
    stop = str(stop)
    num = 2000
    
    #找Index值，從成功的下一隻股票開始找
    for obj in list_of_stock:
        if obj['stock_id'] == stop:
            num = int(obj[''])
            continue
        if int(obj['']) > num :
            Stock_crawl_OTC(obj['stock_id'],obj['stock_name'])
# Out:
# Finmind_daily/6266_daily.csv下載完成...執行時間: 0:00:01.901042 秒
# Finmind_daily/6270_daily.csv下載完成...執行時間: 0:00:01.952692 秒
# Finmind_daily/6274_daily.csv下載完成...執行時間: 0:00:01.550853 秒
# Finmind_daily/6275_daily.csv下載完成...執行時間: 0:00:01.879976 秒
# Finmind_daily/6276_daily.csv下載完成...執行時間: 0:00:02.256231 秒
# Finmind_daily/6279_daily.csv下載完成...執行時間: 0:00:01.571083 秒
# Finmind_daily/6284_daily.csv下載完成...執行時間: 0:00:00.840822 秒
# Finmind_daily/6287_daily.csv下載完成...執行時間: 0:00:03.152471 秒
# Finmind_daily/6290_daily.csv下載完成...執行時間: 0:00:01.031090 秒
# Finmind_daily/6291_daily.csv下載完成...執行時間: 0:00:03.485074 秒
# Finmind_daily/6292_daily.csv下載完成...執行時間: 0:00:02.136055 秒
# Finmind_daily/6294_daily.csv下載完成...執行時間: 0:00:02.976597 秒
# Finmind_daily/6404_daily.csv下載完成...執行時間: 0:00:00.725049 秒
# Finmind_daily/6411_daily.csv下載完成...執行時間: 0:00:01.973848 秒
# Finmind_daily/6417_daily.csv下載完成...執行時間: 0:00:03.185206 秒
# Finmind_daily/6418_daily.csv下載完成...執行時間: 0:00:00.392976 秒
# Finmind_daily/6419_daily.csv下載完成...執行時間: 0:00:01.659903 秒
# Finmind_daily/6425_daily.csv下載完成...執行時間: 0:00:01.220201 秒
# Finmind_daily/6432_daily.csv下載完成...執行時間: 0:00:00.724848 秒
# Finmind_daily/6435_daily.csv下載完成...執行時間: 0:00:01.863105 秒
# Finmind_daily/6441_daily.csv下載完成...執行時間: 0:00:00.517704 秒
# Finmind_daily/6446_daily.csv下載完成...執行時間: 0:00:00.748220 秒
# Finmind_daily/6457_daily.csv下載完成...執行時間: 0:00:00.738164 秒
# Finmind_daily/6461_daily.csv下載完成...執行時間: 0:00:01.356749 秒
# Finmind_daily/6462_daily.csv下載完成...執行時間: 0:00:02.231188 秒
# Finmind_daily/6465_daily.csv下載完成...執行時間: 0:00:01.388838 秒
# Finmind_daily/6469_daily.csv下載完成...執行時間: 0:00:00.553039 秒
# Finmind_daily/6470_daily.csv下載完成...執行時間: 0:00:01.938015 秒
# Finmind_daily/6472_daily.csv下載完成...執行時間: 0:00:02.528841 秒
# Finmind_daily/6482_daily.csv下載完成...執行時間: 0:00:01.544286 秒
# Finmind_daily/6485_daily.csv下載完成...執行時間: 0:00:01.131774 秒
# Finmind_daily/6486_daily.csv下載完成...執行時間: 0:00:01.735110 秒
# Finmind_daily/6488_daily.csv下載完成...執行時間: 0:00:00.668379 秒
# Finmind_daily/6492_daily.csv下載完成...執行時間: 0:00:00.655822 秒
# Finmind_daily/6494_daily.csv下載完成...執行時間: 0:00:01.838657 秒
# Finmind_daily/6496_daily.csv下載完成...執行時間: 0:00:00.738713 秒
# Finmind_daily/6499_daily.csv下載完成...執行時間: 0:00:00.691308 秒
# Finmind_daily/6506_daily.csv下載完成...執行時間: 0:00:00.791448 秒
# Finmind_daily/6508_daily.csv下載完成...執行時間: 0:00:01.862489 秒
# Finmind_daily/6509_daily.csv下載完成...執行時間: 0:00:02.012281 秒
# Finmind_daily/6510_daily.csv下載完成...執行時間: 0:00:00.674572 秒
# Finmind_daily/6512_daily.csv下載完成...執行時間: 0:00:01.379172 秒
# Finmind_daily/6514_daily.csv下載完成...執行時間: 0:00:00.670967 秒
# Finmind_daily/6516_daily.csv下載完成...執行時間: 0:00:00.747236 秒
# Finmind_daily/6523_daily.csv下載完成...執行時間: 0:00:00.665735 秒
# Finmind_daily/6527_daily.csv下載完成...執行時間: 0:00:00.564714 秒
# Finmind_daily/6530_daily.csv下載完成...執行時間: 0:00:01.888782 秒
# Finmind_daily/6532_daily.csv下載完成...執行時間: 0:00:00.616132 秒
# Finmind_daily/6535_daily.csv下載完成...執行時間: 0:00:01.543212 秒
# Finmind_daily/6538_daily.csv下載完成...執行時間: 0:00:00.529465 秒
# Finmind_daily/6542_daily.csv下載完成...執行時間: 0:00:00.504548 秒
# Finmind_daily/6547_daily.csv下載完成...執行時間: 0:00:00.482863 秒
# Finmind_daily/6548_daily.csv下載完成...執行時間: 0:00:00.516758 秒
# Finmind_daily/6556_daily.csv下載完成...執行時間: 0:00:01.743367 秒
# Finmind_daily/6560_daily.csv下載完成...執行時間: 0:00:01.569938 秒
# Finmind_daily/6561_daily.csv下載完成...執行時間: 0:00:01.702574 秒
# Finmind_daily/6568_daily.csv下載完成...執行時間: 0:00:05.987939 秒
# Finmind_daily/6569_daily.csv下載完成...執行時間: 0:00:01.815620 秒
# Finmind_daily/6570_daily.csv下載完成...執行時間: 0:00:00.514797 秒
# Finmind_daily/6574_daily.csv下載完成...執行時間: 0:00:01.527020 秒
# Finmind_daily/6576_daily.csv下載完成...執行時間: 0:00:04.389865 秒
# Finmind_daily/6577_daily.csv下載完成...執行時間: 0:00:05.532644 秒
# Finmind_daily/6578_daily.csv下載完成...執行時間: 0:00:00.452902 秒
# Finmind_daily/6588_daily.csv下載完成...執行時間: 0:00:06.825731 秒
# Finmind_daily/6589_daily.csv下載完成...執行時間: 0:00:01.590206 秒
# Finmind_daily/6590_daily.csv下載完成...執行時間: 0:00:01.013818 秒
# Finmind_daily/6593_daily.csv下載完成...執行時間: 0:00:01.898507 秒
# Finmind_daily/6594_daily.csv下載完成...執行時間: 0:00:01.527103 秒
# Finmind_daily/6596_daily.csv下載完成...執行時間: 0:00:01.740557 秒
# Finmind_daily/6603_daily.csv下載完成...執行時間: 0:00:04.526151 秒
# Finmind_daily/6609_daily.csv下載完成...執行時間: 0:00:03.670084 秒
# Finmind_daily/6612_daily.csv下載完成...執行時間: 0:00:00.724566 秒
# Finmind_daily/6613_daily.csv下載完成...執行時間: 0:00:00.459315 秒
# Finmind_daily/6615_daily.csv下載完成...執行時間: 0:00:00.667798 秒
# Finmind_daily/6616_daily.csv下載完成...執行時間: 0:00:00.476000 秒
# Finmind_daily/6624_daily.csv下載完成...執行時間: 0:00:00.395531 秒
# Finmind_daily/6629_daily.csv下載完成...執行時間: 0:00:02.645895 秒
# Finmind_daily/6640_daily.csv下載完成...執行時間: 0:00:02.721269 秒
# Finmind_daily/6642_daily.csv下載完成...執行時間: 0:00:01.964556 秒
# Finmind_daily/6643_daily.csv下載完成...執行時間: 0:00:02.794760 秒
# Finmind_daily/6649_daily.csv下載完成...執行時間: 0:00:00.431667 秒
# Finmind_daily/6651_daily.csv下載完成...執行時間: 0:00:03.060317 秒
# Finmind_daily/6654_daily.csv下載完成...執行時間: 0:00:00.488293 秒
# Finmind_daily/6661_daily.csv下載完成...執行時間: 0:00:00.945097 秒
# Finmind_daily/6662_daily.csv下載完成...執行時間: 0:00:00.506210 秒
# Finmind_daily/6664_daily.csv下載完成...執行時間: 0:00:01.260119 秒
# Finmind_daily/6667_daily.csv下載完成...執行時間: 0:00:01.602403 秒
# Finmind_daily/6679_daily.csv下載完成...執行時間: 0:00:00.919642 秒
# Finmind_daily/6680_daily.csv下載完成...執行時間: 0:00:01.231260 秒
# Finmind_daily/6683_daily.csv下載完成...執行時間: 0:00:00.616886 秒
# Finmind_daily/6690_daily.csv下載完成...執行時間: 0:00:04.610507 秒
# Finmind_daily/6697_daily.csv下載完成...執行時間: 0:00:09.135341 秒
# Finmind_daily/6703_daily.csv下載完成...執行時間: 0:00:01.253552 秒
# Finmind_daily/6712_daily.csv下載完成...執行時間: 0:00:00.276838 秒
# Finmind_daily/6716_daily.csv下載完成...執行時間: 0:00:02.221612 秒
# Finmind_daily/6727_daily.csv下載完成...執行時間: 0:00:01.394329 秒
# Finmind_daily/6728_daily.csv下載完成...執行時間: 0:00:04.873496 秒
# Finmind_daily/6732_daily.csv下載完成...執行時間: 0:00:00.302133 秒
# Finmind_daily/6733_daily.csv下載完成...執行時間: 0:00:00.515014 秒
# Finmind_daily/6747_daily.csv下載完成...執行時間: 0:00:00.333203 秒
# Finmind_daily/6751_daily.csv下載完成...執行時間: 0:00:00.331024 秒
# Finmind_daily/6752_daily.csv下載完成...執行時間: 0:00:02.653285 秒
# Finmind_daily/6762_daily.csv下載完成...執行時間: 0:00:01.296361 秒
# Finmind_daily/6767_daily.csv下載完成...執行時間: 0:00:03.246145 秒
# Finmind_daily/6803_daily.csv下載完成...執行時間: 0:00:01.826845 秒
# Finmind_daily/7402_daily.csv下載完成...執行時間: 0:00:01.616335 秒
# Finmind_daily/7556_daily.csv下載完成...執行時間: 0:00:00.393073 秒
# Finmind_daily/8024_daily.csv下載完成...執行時間: 0:00:03.499079 秒
# Finmind_daily/8027_daily.csv下載完成...執行時間: 0:00:00.624484 秒
# Finmind_daily/8032_daily.csv下載完成...執行時間: 0:00:02.124239 秒
# Finmind_daily/8034_daily.csv下載完成...執行時間: 0:00:04.537272 秒
# Finmind_daily/8038_daily.csv下載完成...執行時間: 0:00:04.026645 秒
# Finmind_daily/8040_daily.csv下載完成...執行時間: 0:00:01.686714 秒
# Finmind_daily/8042_daily.csv下載完成...執行時間: 0:00:01.870139 秒
# Finmind_daily/8043_daily.csv下載完成...執行時間: 0:00:01.720010 秒
# Finmind_daily/8044_daily.csv下載完成...執行時間: 0:00:03.069899 秒
# Finmind_daily/8047_daily.csv下載完成...執行時間: 0:00:02.041260 秒
# Finmind_daily/8048_daily.csv下載完成...執行時間: 0:00:03.916797 秒
# Finmind_daily/8049_daily.csv下載完成...執行時間: 0:00:01.915949 秒
# Finmind_daily/8050_daily.csv下載完成...執行時間: 0:00:02.871384 秒
# Finmind_daily/8054_daily.csv下載完成...執行時間: 0:00:02.207790 秒
# Finmind_daily/8059_daily.csv下載完成...執行時間: 0:00:03.526026 秒
# Finmind_daily/8064_daily.csv下載完成...執行時間: 0:00:00.836639 秒
# Finmind_daily/8066_daily.csv下載完成...執行時間: 0:00:01.020483 秒
# Finmind_daily/8067_daily.csv下載完成...執行時間: 0:00:02.765439 秒
# Finmind_daily/8068_daily.csv下載完成...執行時間: 0:00:01.808239 秒
# Finmind_daily/8069_daily.csv下載完成...執行時間: 0:00:03.707940 秒
# Finmind_daily/8071_daily.csv下載完成...執行時間: 0:00:01.737673 秒
# Finmind_daily/8074_daily.csv下載完成...執行時間: 0:00:03.395957 秒
# Finmind_daily/8076_daily.csv下載完成...執行時間: 0:00:01.172313 秒
# Finmind_daily/8077_daily.csv下載完成...執行時間: 0:00:02.292272 秒
# Finmind_daily/8083_daily.csv下載完成...執行時間: 0:00:01.963889 秒
# Finmind_daily/8084_daily.csv下載完成...執行時間: 0:00:01.471148 秒
# Finmind_daily/8085_daily.csv下載完成...執行時間: 0:00:02.452465 秒
# Finmind_daily/8086_daily.csv下載完成...執行時間: 0:00:02.275631 秒
# Finmind_daily/8087_daily.csv下載完成...執行時間: 0:00:01.359327 秒
# Finmind_daily/8088_daily.csv下載完成...執行時間: 0:00:01.529511 秒
# Finmind_daily/8089_daily.csv下載完成...執行時間: 0:00:00.421652 秒
# Finmind_daily/8091_daily.csv下載完成...執行時間: 0:00:01.011606 秒
# Finmind_daily/8092_daily.csv下載完成...執行時間: 0:00:00.827604 秒
# Finmind_daily/8093_daily.csv下載完成...執行時間: 0:00:02.448008 秒
# Finmind_daily/8096_daily.csv下載完成...執行時間: 0:00:00.823689 秒
# Finmind_daily/8097_daily.csv下載完成...執行時間: 0:00:01.828672 秒
# Finmind_daily/8099_daily.csv下載完成...執行時間: 0:00:02.371920 秒
# Finmind_daily/8107_daily.csv下載完成...執行時間: 0:00:00.919838 秒
# Finmind_daily/8109_daily.csv下載完成...執行時間: 0:00:00.939822 秒
# Finmind_daily/8111_daily.csv下載完成...執行時間: 0:00:02.332008 秒
# Finmind_daily/8121_daily.csv下載完成...執行時間: 0:00:02.798021 秒
# Finmind_daily/8147_daily.csv下載完成...執行時間: 0:00:04.528166 秒
# Finmind_daily/8155_daily.csv下載完成...執行時間: 0:00:00.833786 秒
# Finmind_daily/8171_daily.csv下載完成...執行時間: 0:00:03.677283 秒
# Finmind_daily/8176_daily.csv下載完成...執行時間: 0:00:00.710384 秒
# Finmind_daily/8182_daily.csv下載完成...執行時間: 0:00:00.865019 秒
# Finmind_daily/8183_daily.csv下載完成...執行時間: 0:00:02.160347 秒
# Finmind_daily/8234_daily.csv下載完成...執行時間: 0:00:06.359317 秒
# Finmind_daily/8240_daily.csv下載完成...執行時間: 0:00:01.728785 秒
# Finmind_daily/8255_daily.csv下載完成...執行時間: 0:00:00.920277 秒
# Finmind_daily/8277_daily.csv下載完成...執行時間: 0:00:00.837973 秒
# Finmind_daily/8279_daily.csv下載完成...執行時間: 0:00:00.486832 秒
# Finmind_daily/8284_daily.csv下載完成...執行時間: 0:00:00.309549 秒
# Finmind_daily/8289_daily.csv下載完成...執行時間: 0:00:00.846029 秒
# Finmind_daily/8291_daily.csv下載完成...執行時間: 0:00:01.668615 秒
# Finmind_daily/8299_daily.csv下載完成...執行時間: 0:00:00.885965 秒
# Finmind_daily/8342_daily.csv下載完成...執行時間: 0:00:03.157125 秒
# Finmind_daily/8349_daily.csv下載完成...執行時間: 0:00:02.047839 秒
# Finmind_daily/8354_daily.csv下載完成...執行時間: 0:00:02.366397 秒
# Finmind_daily/8358_daily.csv下載完成...執行時間: 0:00:00.991377 秒
# Finmind_daily/8383_daily.csv下載完成...執行時間: 0:00:02.421628 秒
# Finmind_daily/8390_daily.csv下載完成...執行時間: 0:00:02.078716 秒
# Finmind_daily/8401_daily.csv下載完成...執行時間: 0:00:01.074839 秒
# Finmind_daily/8403_daily.csv下載完成...執行時間: 0:00:02.493941 秒
# Finmind_daily/8406_daily.csv下載完成...執行時間: 0:00:00.807038 秒
# Finmind_daily/8409_daily.csv下載完成...執行時間: 0:00:01.745554 秒
# Finmind_daily/8410_daily.csv下載完成...執行時間: 0:00:02.082547 秒
# Finmind_daily/8415_daily.csv下載完成...執行時間: 0:00:00.632274 秒
# Finmind_daily/8416_daily.csv下載完成...執行時間: 0:00:02.206855 秒
# Finmind_daily/8418_daily.csv下載完成...執行時間: 0:00:02.758486 秒
# Finmind_daily/8420_daily.csv下載完成...執行時間: 0:00:19.046754 秒
# Finmind_daily/8421_daily.csv下載完成...執行時間: 0:00:11.148844 秒
# Finmind_daily/8423_daily.csv下載完成...執行時間: 0:00:11.793779 秒
# Finmind_daily/8424_daily.csv下載完成...執行時間: 0:00:00.925171 秒
# Finmind_daily/8426_daily.csv下載完成...執行時間: 0:00:00.904142 秒
# Finmind_daily/8431_daily.csv下載完成...執行時間: 0:00:12.810460 秒
# Finmind_daily/8432_daily.csv下載完成...執行時間: 0:00:02.451857 秒
# Finmind_daily/8433_daily.csv下載完成...執行時間: 0:00:00.959715 秒
# Finmind_daily/8435_daily.csv下載完成...執行時間: 0:00:01.430744 秒
# Finmind_daily/8436_daily.csv下載完成...執行時間: 0:00:02.296117 秒
# Finmind_daily/8437_daily.csv下載完成...執行時間: 0:00:00.622921 秒
# Finmind_daily/8440_daily.csv下載完成...執行時間: 0:00:00.490689 秒
# Finmind_daily/8444_daily.csv下載完成...執行時間: 0:00:00.835074 秒
# Finmind_daily/8446_daily.csv下載完成...執行時間: 0:00:00.725012 秒
# Finmind_daily/8450_daily.csv下載完成...執行時間: 0:00:01.675052 秒
# Finmind_daily/8455_daily.csv下載完成...執行時間: 0:00:00.726977 秒
# Finmind_daily/8472_daily.csv下載完成...執行時間: 0:00:00.737804 秒
# Finmind_daily/8476_daily.csv下載完成...執行時間: 0:00:03.361921 秒
# Finmind_daily/8477_daily.csv下載完成...執行時間: 0:00:01.243411 秒
# Finmind_daily/8489_daily.csv下載完成...執行時間: 0:00:06.844334 秒
# Finmind_daily/8905_daily.csv下載完成...執行時間: 0:00:02.788381 秒
# Finmind_daily/8906_daily.csv下載完成...執行時間: 0:00:01.125913 秒
# Finmind_daily/8908_daily.csv下載完成...執行時間: 0:00:00.968094 秒
# Finmind_daily/8916_daily.csv下載完成...執行時間: 0:00:00.874628 秒
# Finmind_daily/8917_daily.csv下載完成...執行時間: 0:00:01.002311 秒
# Finmind_daily/8921_daily.csv下載完成...執行時間: 0:00:01.842775 秒
# Finmind_daily/8923_daily.csv下載完成...執行時間: 0:00:02.891234 秒
# Finmind_daily/8924_daily.csv下載完成...執行時間: 0:00:00.999075 秒
# Finmind_daily/8927_daily.csv下載完成...執行時間: 0:00:05.760161 秒
# Finmind_daily/8928_daily.csv下載完成...執行時間: 0:00:13.487455 秒
# Finmind_daily/8929_daily.csv下載完成...執行時間: 0:00:10.055667 秒
# Finmind_daily/8930_daily.csv下載完成...執行時間: 0:00:02.240803 秒
# Finmind_daily/8931_daily.csv下載完成...執行時間: 0:00:04.056965 秒
# Finmind_daily/8932_daily.csv下載完成...執行時間: 0:00:01.791308 秒
# Finmind_daily/8933_daily.csv下載完成...執行時間: 0:00:06.613307 秒
# Finmind_daily/8935_daily.csv下載完成...執行時間: 0:00:00.959350 秒
# Finmind_daily/8936_daily.csv下載完成...執行時間: 0:00:00.906532 秒
# Finmind_daily/8937_daily.csv下載完成...執行時間: 0:00:01.029582 秒
# Finmind_daily/8938_daily.csv下載完成...執行時間: 0:00:01.044699 秒
# Finmind_daily/8941_daily.csv下載完成...執行時間: 0:00:00.772124 秒
# Finmind_daily/8942_daily.csv下載完成...執行時間: 0:00:03.849839 秒
# Finmind_daily/9949_daily.csv下載完成...執行時間: 0:00:04.188732 秒
# Finmind_daily/9950_daily.csv下載完成...執行時間: 0:00:07.346028 秒
# Finmind_daily/9951_daily.csv下載完成...執行時間: 0:00:00.827223 秒
# Finmind_daily/9960_daily.csv下載完成...執行時間: 0:00:01.035471 秒
# Finmind_daily/9962_daily.csv下載完成...執行時間: 0:00:01.005018 秒
